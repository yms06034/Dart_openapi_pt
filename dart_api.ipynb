# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
import requests
import io
import zipfile
import xmltodict
import pandas as pd
import urllib.request
import json

KEY = "210d7f88b11afefe6715c028448edf2852080412"
url = "https://opendart.fss.or.kr/api/corpCode.xml"

params = {
    "crtfc_key": KEY
}

resp = requests.get(url, params=params)

f = io.BytesIO(resp.content)
zfile = zipfile.ZipFile(f)

xml = zfile.read("CORPCODE.xml").decode("utf-8")
dict_data = xmltodict.parse(xml)

data = dict_data['result']['list']
corp_code_df = pd.DataFrame(data)
corp_code_df.drop(columns=['stock_code', 'modify_date'], inplace=True)

corp_code_df.to_excel("회사코드.xlsx", index=False)

# %%
import random

idx = []
result = []

for i in range(0, 100):
    x = random.randint(1, 100000)
    idx.append(x)

corp_result = corp_code_df.reindex(idx)

for i, text in enumerate(corp_result['corp_code']):
    result.append(text)

# %%
df.to_excel('corp_code.xlsx', index=False)

# %%
for i, re in enumerate(year):
    for j, re_j in enumerate(reprt_code):
        print(re, re_j)

# %%
df = pd.DataFrame(result)
df.dtypes

df.to_excel('corp_code.xlsx', index=False)

# %% [markdown]
# # Code

# %%
import requests
import json

reprt_code = ["11011", "11012", "11013", "11014"]
years = ["2022", "2023"] 
result_data = {}  

mu_url = "https://opendart.fss.or.kr/api/fnlttMultiAcnt.json"

for re_i in years:
    for re in reprt_code:
        params = {
            "crtfc_key": KEY,
            "corp_code": result,
            "bsns_year": re_i,
            "reprt_code": re
        }

        response = requests.get(mu_url, params=params)

        if response.status_code == 200:
            try:
                data = response.json()
                result_data.setdefault(re_i, {})[re] = data
            except json.JSONDecodeError as e:
                print("JSON 디코딩 오류:", e)
        else:
            print("API 요청에 실패하였습니다. 상태 코드:", response.status_code)

for year, data_dict in result_data.items():
    for re, data in data_dict.items():
        print(f"Data for year {year}, reprt_code {re}: {data}")
# Out:
# Data for year 2022, reprt_code 11011: {'status': '000', 'message': '정상', 'list': [{'rcept_no': '20230725000318', 'reprt_code': '11011', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '유동자산', 'thstrm_nm': '제 23 기', 'thstrm_dt': '2022.12.31 현재', 'thstrm_amount': '111,476,875,669', 'frmtrm_nm': '제 22 기', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '97,313,955,633', 'bfefrmtrm_nm': '제 21 기', 'bfefrmtrm_dt': '2020.12.31 현재', 'bfefrmtrm_amount': '89,155,199,266', 'ord': '1', 'currency': 'KRW'}, {'rcept_no': '20230725000318', 'reprt_code': '11011', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '비유동자산', 'thstrm_nm': '제 23 기', 'thstrm_dt': '2022.12.31 현재', 'thstrm_amount': '57,417,494,160', 'frmtrm_nm': '제 22 기', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '62,109,239,996', 'bfefrmtrm_nm': '제 21 기', 'bfefrmtrm_dt': '2020.12.31 현재', 'bfefrmtrm_amount': '62,313,463,931', 'ord': '3', 'currency': 'KRW'}, {'rcept_no': '20230725000318', 'reprt_code': '11011', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '자산총계', 'thstrm_nm': '제 23 기', 'thstrm_dt': '2022.12.31 현재', 'thstrm_amount': '168,894,369,829', 'frmtrm_nm': '제 22 기', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount':
 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '비유동부채', 'thstrm_nm': '제 23 기반기말', 'thstrm_dt': '2022.06.30 현재', 'thstrm_amount': '1,440,215,223', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '2,301,631,410', 'ord': '9', 'currency': 'KRW'}, {'rcept_no': '20220816000730', 'reprt_code': '11012', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '부채총계', 'thstrm_nm': '제 23 기반기말', 'thstrm_dt': '2022.06.30 현재', 'thstrm_amount': '24,644,468,827', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '31,450,398,252', 'ord': '11', 'currency': 'KRW'}, {'rcept_no': '20220816000730', 'reprt_code': '11012', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '자본총계', 'thstrm_nm': '제 23 기반기말', 'thstrm_dt': '2022.06.30 현재', 'thstrm_amount': '128,479,761,342', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '127,972,797,377', 'ord': '21', 'currency': 'KRW'}, {'rcept_no': '20220816000730', 'reprt_code': '11012', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'IS', 'sj_nm': '손익계산서', 'account_nm': '매출액', 'thstrm_nm': '제 23 기반기', 'thstrm_dt': '2022.01.01 ~ 2022.06.30', 'thstrm_amount': '17,869,912,154', 'thstrm_add_amount': '28,992,373,456', 'frmtrm_nm': '제 22 기반기', 'frmtrm_dt': '2021.01.01 ~ 2021.06.30', 'frmtrm_add_amount': '25,575,417,641', 'frmtrm_amount': '13,691,770,630', 'ord': '23', 'currency': 'KRW'}, {'rcept_no': '20220816000730', 'reprt_code': '11012', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'IS', 'sj_nm': '손익계산서', 'account_nm': '영업이익', 'thstrm_nm': '제 23 기반기', 'thstrm_dt': '2022.01.01 ~ 2022.06.30', 'thstrm_amount': '1,880,767,231', 'thstrm_add_amount': '-349,601,405', 'frmtrm_nm': '제 22 기반기', 'frmtrm_dt':  ...
# Data for year 2022, reprt_code 11013: {'status': '000', 'message': '정상', 'list': [{'rcept_no': '20220513001069', 'reprt_code': '11013', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '유동자산', 'thstrm_nm': '제 23 기1분기말', 'thstrm_dt': '2022.03.31 현재', 'thstrm_amount': '90,775,206,646', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '97,313,955,633', 'ord': '1', 'currency': 'KRW'}, {'rcept_no': '20220513001069', 'reprt_code': '11013', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '비유동자산', 'thstrm_nm': '제 23 기1분기말', 'thstrm_dt': '2022.03.31 현재', 'thstrm_amount': '63,331,814,414', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '62,109,239,996', 'ord': '3', 'currency': 'KRW'}, {'rcept_no': '20220513001069', 'reprt_code': '11013', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '자산총계', 'thstrm_nm': '제 23 기1분기말', 'thstrm_dt': '2022.03.31 현재', 'thstrm_amount': '154,107,021,060', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '159,423,195,629', 'ord': '5', 'currency': 'KRW'}, {'rcept_no': '20220513001069', 'reprt_code': '11013', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '유동부채', 'thstrm_nm': '제 23 기1분기말', 'thstrm_dt': '2022.03.31 현재', 'thstrm_amount': '25,346,236,950', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '29,148,766,842', 'ord': '7', 'currency': 'KRW'}, {'rcept_no': '20220513001069', 'reprt_code': '11013', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '비유동부채', 'thstrm_nm': '제 23 기1분기말', 'thstrm_dt': '2022.03.31 현재', 'thstrm_amount': '2,663,571,831', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '2,301,631,410', 'ord': '9', 'currency': 'KRW'}, {'rcept_no': '20220513001069', 'reprt_code': '11013', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '부채총계', 'thstrm_nm': '제 23 기1분기말', 'thstrm_dt': '2022.03.31 현재', 'thstrm_amount': '28,009,808,781', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '31,450,398,252', 'ord': '11', 'currency': 'KRW'}, {'rcept_no': '20220513001069', 'reprt_code': '11013', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '자본총계', 'thstrm_nm': '제 23 기1분기말', 'thstrm_dt': '2022.03.31 현재', 'thstrm_amount': '126,097,212,279', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '127,972,797,377', 'ord': '21', 'currency': 'KRW'}, {'rcept_no': '20220513001069', 'reprt_code': '11013', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'IS', 'sj_nm': '손익계산서', 'account_nm': '매출액', 'thstrm_nm': '제 23 기1분기', 'thstrm_dt': '2022.01.01 ~ 2022.03.31', 'thstrm_amount': '11,116,861,302', 'thstrm_add_amount': '11,116,861,302', 'frmtrm_nm': '제 22 기1분기', 'frmtrm_dt': '2021.01.01 ~ 2021.03.31', 'frmtrm_add_amount': '11,883,647,011', 'frmtrm_amount': '11,883,647,011', 'ord': '23', 'currency': 'KRW'}, {'rcept_no': '20220513001069', 'reprt_code': '11013', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'IS', 'sj_nm': '손익계산서', 'account_nm': '영업이익', 'thstrm_nm': '제 23 기1분기', 'thstrm_dt': '2022.01.01 ~ 2022.03.31', 'thstrm_amount': '-2,230,368,636', 'thstrm_add_amount': '-2,230,368,636', 'frmtrm_nm': '제 22 기1분기', ...
# Data for year 2022, reprt_code 11014: {'status': '000', 'message': '정상', 'list': [{'rcept_no': '20221114001918', 'reprt_code': '11014', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '유동자산', 'thstrm_nm': '제 23 기3분기말', 'thstrm_dt': '2022.09.30 현재', 'thstrm_amount': '96,574,841,922', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '97,313,955,633', 'ord': '1', 'currency': 'KRW'}, {'rcept_no': '20221114001918', 'reprt_code': '11014', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '비유동자산', 'thstrm_nm': '제 23 기3분기말', 'thstrm_dt': '2022.09.30 현재', 'thstrm_amount': '56,571,967,670', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '62,109,239,996', 'ord': '3', 'currency': 'KRW'}, {'rcept_no': '20221114001918', 'reprt_code': '11014', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '자산총계', 'thstrm_nm': '제 23 기3분기말', 'thstrm_dt': '2022.09.30 현재', 'thstrm_amount': '153,146,809,592', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '159,423,195,629', 'ord': '5', 'currency': 'KRW'}, {'rcept_no': '20221114001918', 'reprt_code': '11014', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '유동부채', 'thstrm_nm': '제 23 기3분기말', 'thstrm_dt': '2022.09.30 현재', 'thstrm_amount': '20,630,969,251', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '29,148,766,842', 'ord': '7', 'currency': 'KRW'}, {'rcept_no': '20221114001918', 'reprt_code': '11014', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '비유동부채', 'thstrm_nm': '제 23 기3분기말', 'thstrm_dt': '2022.09.30 현재', 'thstrm_amount': '1,523,085,089', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '2,301,631,410', 'ord': '9', 'currency': 'KRW'}, {'rcept_no': '20221114001918', 'reprt_code': '11014', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '부채총계', 'thstrm_nm': '제 23 기3분기말', 'thstrm_dt': '2022.09.30 현재', 'thstrm_amount': '22,154,054,340', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '31,450,398,252', 'ord': '11', 'currency': 'KRW'}, {'rcept_no': '20221114001918', 'reprt_code': '11014', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '자본총계', 'thstrm_nm': '제 23 기3분기말', 'thstrm_dt': '2022.09.30 현재', 'thstrm_amount': '130,992,755,252', 'frmtrm_nm': '제 22 기말', 'frmtrm_dt': '2021.12.31 현재', 'frmtrm_amount': '127,972,797,377', 'ord': '21', 'currency': 'KRW'}, {'rcept_no': '20221114001918', 'reprt_code': '11014', 'bsns_year': '2022', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 
 'bsns_year': '2023', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '부채총계', 'thstrm_nm': '제 24 기1분기말', 'thstrm_dt': '2023.03.31 현재', 'thstrm_amount': '24,190,984,876', 'frmtrm_nm': '제 23 기말', 'frmtrm_dt': '2022.12.31 현재', 'frmtrm_amount': '37,193,425,163', 'ord': '11', 'currency': 'KRW'}, {'rcept_no': '20230515001497', 'reprt_code': '11013', 'bsns_year': '2023', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_nm': '자본총계', 'thstrm_nm': '제 24 기1분기말', 'thstrm_dt': '2023.03.31 현재', 'thstrm_amount': '130,718,231,998', 'frmtrm_nm': '제 23 기말', 'frmtrm_dt': '2022.12.31 현재', 'frmtrm_amount': '131,700,944,666', 'ord': '21', 'currency': 'KRW'}, {'rcept_no': '20230515001497', 'reprt_code': '11013', 'bsns_year': '2023', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'IS', 'sj_nm': '손익계산서', 'account_nm': '매출액', 'thstrm_nm': '제 24 기1분기', 'thstrm_dt': '2023.01.01 ~ 2023.03.31', 'thstrm_amount': '10,968,750,133', 'thstrm_add_amount': '10,968,750,133', 'frmtrm_nm': '제 23 기1분기', 'frmtrm_dt': '2022.01.01 ~ 2022.03.31', 'frmtrm_add_amount': '11,116,861,302', 'frmtrm_amount': '11,116,861,302', 'ord': '23', 'currency': 'KRW'}, {'rcept_no': '20230515001497', 'reprt_code': '11013', 'bsns_year': '2023', 'corp_code': '00360674', 'stock_code': '056360', 'fs_div': 'CFS', 'fs_nm': '연결재무제표', 'sj_div': 'IS', 'sj_nm': '손익계산서', 'account_nm': '영업이익', 'thstrm_nm': '제 24 기1분기', 'thstrm_dt': '2023.01.01 ~ 2023.03.31', 'thstrm_amount': '-2,199,046,889', 'thstrm_add_amount': '-2,199,046,889', 'frmtrm_nm': '제 23 기1분기' ...
# Data for year 2023, reprt_code 11014: {'status': '013', 'message': '조회된 데이타가 없습니다.'}

# %%
if result_data['2023']['11011']['status'] == '000':
    df_23_11011 = result_data['2023']['11011']['list']
    
    df_23_11011 = pd.DataFrame(df_23_11011)
    df_23_11011.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)
    
    df_23_11011['thstrm_amount'] = pd.to_numeric(df_23_11011['thstrm_amount'].str.replace(',', ''), errors='coerce')

    df_23_11011.insert(8, '월평균(백만원)', df_23_11011['thstrm_amount']//12)

    df_23_11011['thstrm_amount'] = df_22_11011['thstrm_amount'].apply(lambda x: "{:,}".format(x))
    df_23_11011['월평균(백만원)'] = df_22_11011['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

    df_23_11011.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "전전기명", "전전기일자", "전전기금액"]
else:
    df_23_11011 = {}
    df_23_11011 = pd.DataFrame(df_23_11011)
    
if result_data['2023']['11012']['status'] == '000':
    df_23_11012 = result_data['2023']['11012']['list']
    
    df_23_11012 = pd.DataFrame(df_23_11012)
    df_23_11012.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)
    
    df_23_11012['thstrm_amount'] = pd.to_numeric(df_23_11012['thstrm_amount'].str.replace(',', ''), errors='coerce')

    df_23_11012.insert(8, '월평균(백만원)', df_23_11012['thstrm_amount']//6)

    df_23_11012['thstrm_amount'] = df_23_11012['thstrm_amount'].apply(lambda x: "{:,}".format(x))
    df_23_11012['월평균(백만원)'] = df_23_11012['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

    df_23_11012.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "당기누적금액", "전기누적금액"]
else:
    df_23_11012 = {}
    df_23_11012 = pd.DataFrame(df_23_11012)

if result_data['2023']['11013']['status'] == '000':
    df_23_11013 = result_data['2023']['11013']['list']
    
    df_23_11013 = pd.DataFrame(df_23_11013)
    df_23_11013.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)
    
    df_23_11013['thstrm_amount'] = pd.to_numeric(df_23_11013['thstrm_amount'].str.replace(',', ''), errors='coerce')

    df_23_11013.insert(8, '월평균(백만원)', df_23_11013['thstrm_amount']//3)

    df_23_11013['thstrm_amount'] = df_23_11013['thstrm_amount'].apply(lambda x: "{:,}".format(x))
    df_23_11013['월평균(백만원)'] = df_23_11013['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

    df_23_11013.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "당기누적금액", "전기누적금액"]
else:
    df_23_11013 = {}
    df_23_11013 = pd.DataFrame(df_23_11013)
    
if result_data['2023']['11014']['status'] == '000':
    df_23_11014 = result_data['2023']['11014']['list']
    
    df_23_11014 = pd.DataFrame(df_23_11014)
    df_23_11014.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)
    
    df_23_11014['thstrm_amount'] = pd.to_numeric(df_23_11014['thstrm_amount'].str.replace(',', ''), errors='coerce')

    df_23_11014.insert(8, '월평균(백만원)', df_23_11014['thstrm_amount']//3)

    df_23_11014['thstrm_amount'] = df_23_11014['thstrm_amount'].apply(lambda x: "{:,}".format(x))
    df_23_11014['월평균(백만원)'] = df_23_11014['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

    df_23_11014.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "당기누적금액", "전기누적금액"]
else:
    df_23_11014 = {}
    df_23_11014 = pd.DataFrame(df_23_11014)

# %%
if result_data['2022']['11011']['status'] == '000':
    df_22_11011 = result_data['2022']['11011']['list']
    
    df_22_11011 = pd.DataFrame(df_22_11011)
    df_22_11011.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)
    
    df_22_11011['thstrm_amount'] = pd.to_numeric(df_22_11011['thstrm_amount'].str.replace(',', ''), errors='coerce')

    df_22_11011.insert(8, '월평균(백만원)', df_22_11011['thstrm_amount']//12)

    df_22_11011['thstrm_amount'] = df_22_11011['thstrm_amount'].apply(lambda x: "{:,}".format(x))
    df_22_11011['월평균(백만원)'] = df_22_11011['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

    df_22_11011.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "전전기명", "전전기일자", "전전기금액"]
else:
    df_22_11011 = {}
    df_22_11011 = pd.DataFrame(df_22_11011)
    
if result_data['2022']['11012']['status'] == '000':
    df_22_11012 = result_data['2022']['11012']['list']
    
    df_22_11012 = pd.DataFrame(df_22_11012)
    df_22_11012.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)
    
    df_22_11012['thstrm_amount'] = pd.to_numeric(df_22_11012['thstrm_amount'].str.replace(',', ''), errors='coerce')

    df_22_11012.insert(8, '월평균(백만원)', df_22_11012['thstrm_amount']//6)

    df_22_11012['thstrm_amount'] = df_22_11012['thstrm_amount'].apply(lambda x: "{:,}".format(x))
    df_22_11012['월평균(백만원)'] = df_22_11012['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

    df_22_11012.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "당기누적금액", "전기누적금액"]
else:
    df_22_11012 = {}
    df_22_11012 = pd.DataFrame(df_22_11012)

if result_data['2022']['11013']['status'] == '000':
    df_22_11013 = result_data['2022']['11013']['list']
    
    df_22_11013 = pd.DataFrame(df_22_11013)
    df_22_11013.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)
    
    df_22_11013['thstrm_amount'] = pd.to_numeric(df_22_11013['thstrm_amount'].str.replace(',', ''), errors='coerce')

    df_22_11013.insert(8, '월평균(백만원)', df_22_11013['thstrm_amount']//3)

    df_22_11013['thstrm_amount'] = df_22_11013['thstrm_amount'].apply(lambda x: "{:,}".format(x))
    df_22_11013['월평균(백만원)'] = df_22_11013['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

    df_22_11013.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "당기누적금액", "전기누적금액"]
else:
    df_22_11013 = {}
    df_22_11013 = pd.DataFrame(df_22_11013)
    
if result_data['2022']['11014']['status'] == '000':
    df_22_11014 = result_data['2022']['11014']['list']
    
    df_22_11014 = pd.DataFrame(df_22_11014)
    df_22_11014.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)
    
    df_22_11014['thstrm_amount'] = pd.to_numeric(df_22_11014['thstrm_amount'].str.replace(',', ''), errors='coerce')

    df_22_11014.insert(8, '월평균(백만원)', df_22_11014['thstrm_amount']//3)

    df_22_11014['thstrm_amount'] = df_22_11014['thstrm_amount'].apply(lambda x: "{:,}".format(x))
    df_22_11014['월평균(백만원)'] = df_22_11014['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

    df_22_11014.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "당기누적금액", "전기누적금액"]
else:
    df_22_11014 = {}
    df_22_11014 = pd.DataFrame(df_22_11014)

# %%
dataframes_23 = [df_23_11013, df_23_11014, df_23_11012]
dataframes_22 = [df_22_11013, df_22_11014, df_22_11012]

true_23_dataframes = []
true_22_dataframes = []

for df_23 in dataframes_23:
    if not df_23.empty:
        true_23_dataframes.append(df_23)
        
for df_22 in dataframes_22:
    if not df_22.empty:
        true_22_dataframes.append(df_22)
        
combined_23_df = pd.concat(true_23_dataframes, axis=0)
combined_23_df.reset_index(drop=True, inplace=True)

combined_22_df = pd.concat(true_22_dataframes, axis=0)
combined_22_df.reset_index(drop=True, inplace=True)

# %%
all_dataframes = [combined_22_df, combined_23_df]
all_combined_df = pd.concat(all_dataframes, axis=0)
all_combined_df.reset_index(drop=True, inplace=True)

# %%
dfs_11011 = [df_23_11011, df_22_11011]
true_dfs_11011 = []

for df in dfs_11011:
    if not df.empty:
        true_dfs_11011.append(df)
        
if len(true_dfs_11011) > 1:
    all_combined_11011_df = pd.concat(true_dfs_11011, axis=0)
    all_combined_11011_df.reset_index(drop=True, inplace=True)
else:
    all_combined_11011_df = true_dfs_11011[0]

# %% [markdown]
# # Code Refactring

# %%
import requests
import json
import pandas as pd

reprt_code = ["11011", "11012", "11013", "11014"]
years = ["2022", "2023"] 
result_data = {}  

mu_url = "https://opendart.fss.or.kr/api/fnlttMultiAcnt.json"

for re_i in years:
    for re in reprt_code:
        params = {
            "crtfc_key": KEY,
            "corp_code": result,
            "bsns_year": re_i,
            "reprt_code": re
        }

        response = requests.get(mu_url, params=params)

        if response.status_code == 200:
            try:
                data = response.json()
                result_data.setdefault(re_i, {})[re] = data
            except json.JSONDecodeError as e:
                print("JSON 디코딩 오류:", e)
        else:
            print("API 요청에 실패하였습니다. 상태 코드:", response.status_code)

def data_processing(data, year, code):
    if data[year][code]['status'] == '000': 
        data_df = data[year][code]['list']
        df = pd.DataFrame(data_df)
        df.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)

        df['thstrm_amount'] = pd.to_numeric(df['thstrm_amount'].str.replace(',', ''), errors='coerce')

        df.insert(8, '월평균(백만원)', df['thstrm_amount'] // (12 if code == '11011' else 6 if code == '11012' else 3))
        df['월평균(백만원)'] = df['월평균(백만원)'] // (1000000)
        df['thstrm_amount'] = df['thstrm_amount'].apply(lambda x: "{:,}".format(x))
        df['월평균(백만원)'] = df['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

        if df.shape[1] == 15:
            df.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "전전기명", "전전기일자", "전전기금액"]
            df.drop(["전전기명", "전전기일자", "전전기금액"], inplace=True, axis=1)
        else:
            df.columns = ["사업 연도", "회사코드", "종목코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "당기누적금액", "전기누적금액"]
        return df
    else:
        empty_df = {}
        df = pd.DataFrame(empty_df)
        return df

dataframes = {}

for year in years:
    for code in reprt_code:
        df = data_processing(result_data, year, code)
        if not df.empty:
            dataframes[f'df_{year}_{code}'] = df

            
combined_dfs = [df for df in dataframes.values()]
            
if combined_dfs:
    all_combined_df = pd.concat(combined_dfs, join='outer', ignore_index=True)
    all_combined_df.reset_index(drop=True, inplace=True)
else:
    all_combined_df = pd.DataFrame()

# all_combined_df

# %%
all_combined_df.to_excel('test.xlsx', index=False)

# %%
import pandas as pd

# 두 개의 데이터프레임 생성 (이 부분은 실제 데이터프레임을 생성하는 코드로 대체해야 합니다)
df1 = pd.DataFrame({'사업 연도': [2022, 2023], '회사코드': [1, 2], '재무제표명': ['제무제표1', '제무제표2']})
df2 = pd.DataFrame({'사업 연도': [2022, 2023], '회사코드': [3, 4], '재무제표명': ['제무제표3', '제무제표4'], '전전기명': ['전전기1', '전전기2']})

# 데이터프레임을 합칠 때 join 옵션을 사용하여 공통 열을 기준으로 합칩니다. 없는 값은 NaN으로 처리됩니다.
merged_df = pd.concat([df1, df2], join='outer', ignore_index=True)

merged_df
# Out:
#    사업 연도  회사코드  재무제표명  전전기명
# 0   2022     1  제무제표1   NaN
# 1   2023     2  제무제표2   NaN
# 2   2022     3  제무제표3  전전기1
# 3   2023     4  제무제표4  전전기2

# %%
true_dataframes = []

for df in dataframes:
    if not dataframes[df].empty:
        true_dataframes.append(f"dataframes['{df}']")

# %%
true_dataframes
# Out:
# ["dataframes['df_2022_11011']",
#  "dataframes['df_2022_11012']",
#  "dataframes['df_2022_11013']",
#  "dataframes['df_2022_11014']",
#  "dataframes['df_2023_11012']",
#  "dataframes['df_2023_11013']"]

# %%
true_dataframes
# Out:
# ['df_2022_11011',
#  'df_2022_11012',
#  'df_2022_11013',
#  'df_2022_11014',
#  'df_2023_11012',
#  'df_2023_11013']

# %%
true_22_dataframes = []

for df_23 in dataframes_23:
    if not df_23.empty:
        true_23_dataframes.append(df_23)

# %%
import requests
import json
import pandas as pd

# Define your API key (replace 'YOUR_API_KEY' with your actual API key)
KEY = 'YOUR_API_KEY'

report_codes = ["11011", "11012", "11013", "11014"]
years = ["2022", "2023"]
result_data = {}

mu_url = "https://opendart.fss.or.kr/api/fnlttMultiAcnt.json"

def fetch_data(year, report_code):
    params = {
        "crtfc_key": KEY,
        "corp_code": result,
        "bsns_year": year,
        "reprt_code": report_code
    }

    response = requests.get(mu_url, params=params)

    if response.status_code == 200:
        try:
            data = response.json()
            return data
        except json.JSONDecodeError as e:
            return None, f"JSON decoding error: {e}"
    else:
        return None, f"API request failed with status code: {response.status_code}"

def process_data(data):
    if data is not None and data.get('status') == '000':
        df = pd.DataFrame(data['list'])
        df.drop(['rcept_no', 'reprt_code', 'fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1, inplace=True)
        df['thstrm_amount'] = pd.to_numeric(df['thstrm_amount'].str.replace(',', ''), errors='coerce')
        df.insert(8, '월평균(백만원)', df['thstrm_amount'] // (12 if code == '11011' else 3 if code == '11013' else 6))
        df['thstrm_amount'] = df['thstrm_amount'].apply(lambda x: "{:,}".format(x))
        df['월평균(백만원)'] = df['월평균(백만원)'].apply(lambda x: "{:,}".format(x))
        return df
    else:
        return None

for year in years:
    for report_code in report_codes:
        result, error_message = fetch_data(year, report_code)
        if error_message:
            print(error_message)
        else:
            df = process_data(result)
            if df is not None:
                result_data.setdefault(year, {}).setdefault(report_code, df)

# %%
all_combined_df.to_excel("100개_1분기_반기_3분기_통합.xlsx", index=False)
all_combined_11011_df.to_excel("100개_사업보고서.xlsx", index=False)

# %%
common_columns = list(set(all_combined_df.columns) | set(all_combined_11011_df.columns))

for col in common_columns:
    if col not in all_combined_df.columns:
        all_combined_df[col] = np.nan
    if col not in all_combined_11011_df.columns:
        all_combined_11011_df[col] = np.nan

final_combined_df = pd.concat([all_combined_df, all_combined_11011_df], ignore_index=True)

# %% [markdown]
# ---------------

# %% [markdown]
# # 상장기업 재무정보
# ## 단일회사 전체 재무제표

# %%
# !pip install --upgrade pyOpenSSL
import requests
import json

reprt_codes = ["11011", "11012", "11013", "11014"]
years = ["2022", "2023"] 
statements_result_data = {}  

mu_url = "https://opendart.fss.or.kr/api/fnlttMultiAcnt.json"

for year in years:
    year_data = {}  # Create a dictionary to store data for the current year

    for code in reprt_codes:
        for re in result:
            params = {
                "crtfc_key": KEY,
                "corp_code": re,
                "bsns_year": year,
                "reprt_code": code
            }

            response = requests.get(mu_url, params=params)

            if response.status_code == 200:
                try:
                    data = response.json()
                    year_data.setdefault(code, {})[re] = data  # Store data for the current year and code
                except json.JSONDecodeError as e:
                    print("JSON 디코딩 오류:", e)
            else:
                print("API 요청에 실패하였습니다. 상태 코드:", response.status_code)

    statements_result_data[year] = year_data
# Out:
# Requirement already satisfied: pyOpenSSL in c:\users\user\anaconda3\lib\site-packages (23.0.0)
# Collecting pyOpenSSL
#   Downloading pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#      ---------------------------------------- 59.0/59.0 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0 in c:\users\user\anaconda3\lib\site-packages (from pyOpenSSL) (39.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\user\anaconda3\lib\site-packages (from cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.12->cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL) (2.21)
# Installing collected packages: pyOpenSSL
#   Attempting uninstall: pyOpenSSL
#     Found existing installation: pyOpenSSL 23.0.0
#     Uninstalling pyOpenSSL-23.0.0:
#       Successfully uninstalled pyOpenSSL-23.0.0
# Successfully installed pyOpenSSL-23.2.0

# %%
def data_process(data, year, code, i):
    data_df = data[year][f'{code}'][f'{i}']['list']
    df = pd.DataFrame(data_df)

    df.drop(['rcept_no', 'reprt_code', 'stock_code','fs_div', 'fs_nm', 'sj_div', 'ord', 'currency'], axis=1,inplace=True)
    df['thstrm_amount'] = pd.to_numeric(df['thstrm_amount'].str.replace(',', ''), errors='coerce')

    df.insert(7, '월평균(백만원)', df['thstrm_amount'] // 12)
    df['월평균(백만원)'] = df['월평균(백만원)'] // (1000000)
    df['thstrm_amount'] = df['thstrm_amount'].apply(lambda x: "{:,}".format(x))
    df['월평균(백만원)'] = df['월평균(백만원)'].apply(lambda x: "{:,}".format(x))

    if df.shape[1] == 14:
        df.columns = ["사업 연도", "회사코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "전전기명", "전전기일자", "전전기금액"]
        df.drop(["전전기명", "전전기일자", "전전기금액"], inplace=True, axis=1)
    else:
        df.columns = ["사업 연도", "회사코드", "재무제표명", "계정명", "당기명", "당기일자", "당기금액", "월평균(백만원)","전기명", "전기일자", "전기금액", "당기누적금액", "전기누적금액"]
    return df
            
dataframes = {}

if (statements_result_data['2022'] or statements_result_data['2023']):
    for year in years:
        for idx, code in enumerate(reprt_codes):
            for i in statements_result_data[year][f'{code}']:
                if (statements_result_data[year][f'{code}'][f'{i}']['status'] == '000'):
    #                 print(statements_result_data[year][f'{code}'][f'{i}']['list'])
                    df = data_process(statements_result_data, year, code, i)
                    print(df)
                    dataframes[f'df_{year}_{code}_{i}'] = df

    combined_dfs = [df for df in dataframes.values()]

    if combined_dfs:
        all_combined_df = pd.concat(combined_dfs, join='outer', ignore_index=True)
        all_combined_df.reset_index(drop=True, inplace=True)
    else:
        all_combined_df = pd.DataFrame()

    all_combined_df.to_excel(f'다중회사_주요계정_.xlsx', index=False)
else:
    print('데이터가 없음')
# Out:
#    사업 연도      회사코드  재무제표명         계정명     당기명                     당기일자  \
# 0   2022  00536541  재무상태표        유동자산  제 25 기            2022.12.31 현재
# 1   2022  00536541  재무상태표       비유동자산  제 25 기            2022.12.31 현재
# 2   2022  00536541  재무상태표        자산총계  제 25 기            2022.12.31 현재
# 3   2022  00536541  재무상태표        유동부채  제 25 기            2022.12.31 현재
# 4   2022  00536541  재무상태표       비유동부채  제 25 기            2022.12.31 현재
# 5   2022  00536541  재무상태표        부채총계  제 25 기            2022.12.31 현재
# 6   2022  00536541  재무상태표        자본총계  제 25 기            2022.12.31 현재
# 7   2022  00536541  손익계산서         매출액  제 25 기  2022.01.01 ~ 2022.12.31
# 8   2022  00536541  손익계산서        영업이익  제 25 기  2022.01.01 ~ 2022.12.31
# 9   2022  00536541  손익계산서  법인세차감전 순이익  제 25 기  2022.01.01 ~ 2022.12.31
# 10  2022  00536541  손익계산서       당기순이익  제 25 기  2022.01.01 ~ 2022.12.31
# 11  2022  00536541  재무상태표        유동자산  제 25 기            2022.12.31 현재
# 12  2022  00536541  재무상태표       비유동자산  제 25 기            2022.12.31 현재
# 13  2022  00536541  재무상태표        자산총계  제 25 기            2022.12.31 현재
# 14  2022  00536541  재무상태표        유동부채  제 25 기            2022.12.31 현재
# 15  2022  00536541  재무상태표       비유동부채  제 25 기            2022.12.31 현재
# 16  2022  00536541  재무상태표        부채총계  제 25 기            2022.12.31 현재
# 17  2022  00536541  재무상태표         자본금  제 25 기            2022.12.31 현재
# 18  2022  00536541  재무상태표       이익잉여금  제 25 기            2022.12.31 현재
# 19  2022  00536541  재무상태표        자본총계  제 25 기            2022.12.31 현재
# 20  2022  00536541  손익계산서        영업이익  제 25 기  2022.01.01 ~ 2022.12.31
# 21  2022  00536541  손익계산서  법인세차감전 순이익  제 25 기  2022.01.01 ~ 2022.12.31
# 22  2022  00536541  손익계산서       당기순이익  제 25 기  2022.01.01 ~ 2022.12.31
#
#                  당기금액 월평균(백만원)     전기명                     전기일자  \
# 0   3,162,551,112,304  263,545  제 24 기            2021.12.31 현재
# 1   2,183,231,490,740  181,935  제 24 기            2021.12.31 현재
# 2   5,345,782,603,044  445,481  제 24 기            2021.12.31 현재
# 3   2,082,665,018,806  173,555  제 24 기            2021.12.31 현재
# 4     741,336,930,529   61,778  제 24 기            2021.12.31 현재
# 5   2,824,001,949,335  235,333  제 24 기            2021.12.31 현재
# 6   2,521,780,653,709  210,148  제 24 기            2021.12.31 현재
# 7   5,639,741,327,318  469,978  제 24 기  2021.01.01 ~ 2021.12.31
# 8     613,226,487,106   51,102  제 24 기  2021.01.01 ~ 2021.12.31
# 9     306,616,814,981   25,551  제 24 기  2021.01.01 ~ 2021.12.31
# 10    220,591,650,311   18,382  제 24 기  2021.01.01 ~ 2021.12.31
# 11     85,518,930,923    7,126  제 24 기            2021.12.31 현재
# 12    766,097,598,715   63,841  제 24 기            2021.12.31 현재
# 13    851,616,529,638   70,968  제 24 기            2021.12.31 현재
# 14    131,486,088,494   10,957  제 24 기            2021.12.31 현재
# 15    161,898,786,837   13,491  제 24 기            2021.12.31 현재
# 16    293,384,875,331   24,448  제 24 기            2021.12.31 현재
# 17     12,628,762,500    1,052  제 24 기            2021.12.31 현재
# 18    391,212,235,688   32,601  제 24 기            2021.12.31 현재
# 19    558,231,654,307   46,519  제 24 기            2021.12.31 현재
# 20    114,769,395,263    9,564  제 24 기  2021.01.01 ~ 2021.12.31
# 21    -91,477,140,110   -7,624  제 24 기  2021.01.01 ~ 2021.12.31
# 22    -86,162,845,740   -7,181  제 24 기  2021.01.01 ~ 2021.12.31
#
#                  전기금액
# 0   1,619,673,745,793
# 1   1,780,771,227,611
# 2   3,400,444,973,404
# 3     967,353,222,621
# 4     736,177,922,357
# 5   1,703,531,144,978
# 6   1,696,913,828,426
# 7   1,504,191,410,850
# 8      85,956,918,350
# 9    -171,540,107,753
# 10    278,561,242,483
# 11    177,020,398,734
# 12    623,330,894,263
# 13    800,351,292,997
# 14     28,236,680,327
# 15    207,321,136,940
# 16    235,557,817,267
# 17     11,987,836,000
# 18    453,961,804,789
# 19    564,793,475,730
# 20      4,161,625,636
# 21   -132,657,523,447
# 22    384,971,966,571
#    사업 연도      회사코드  재무제표명         계정명     당기명                     당기일자  \
# 23  2022  00536541  손익계산서       당기순이익   제 25 기반기  2022.01.01 ~ 2022.06.30
#
#                  당기금액 월평균(백만원)       전기명                     전기일자  \
# 0   3,125,556,642,632  260,463   제 24 기말            2021.12.31 현재
# 1   2,077,232,774,569  173,102   제 24 기말            2021.12.31 현재
# 2   5,202,789,417,201  433,565   제 24 기말            2021.12.31 현재
# 3   2,051,953,806,919  170,996   제 24 기말            2021.12.31 현재
# 4     854,804,419,267   71,233   제 24 기말            2021.12.31 현재
# 5   2,906,758,226,186  242,229   제 24 기말            2021.12.31 현재
# 6   2,296,031,191,015  191,335   제 24 기말            2021.12.31 현재
# 7   1,231,803,718,208  102,650  제 24 기반기  2021.01.01 ~ 2021.06.30
# 8     169,910,777,026   14,159  제 24 기반기  2021.01.01 ~ 2021.06.30
# 9     112,167,729,835    9,347  제 24 기반기  2021.01.01 ~ 2021.06.30
# 10    102,435,944,190    8,536  제 24 기반기  2021.01.01 ~ 2021.06.30
# 11     42,514,090,112    3,542   제 24 기말            2021.12.31 현재
# 12    891,601,148,583   74,300   제 24 기말            2021.12.31 현재
# 13    934,115,238,695   77,842   제 24 기말            2021.12.31 현재
# 14    139,390,730,692   11,615   제 24 기말            2021.12.31 현재
# 15    212,568,123,657   17,714   제 24 기말            2021.12.31 현재
# 16    351,958,854,349   29,329   제 24 기말            2021.12.31 현재
# 17     12,225,437,500    1,018   제 24 기말            2021.12.31 현재
# 18    457,399,630,078   38,116   제 24 기말            2021.12.31 현재
# 19    582,156,384,346   48,513   제 24 기말            2021.12.31 현재
# 20      6,231,713,000      519  제 24 기반기  2021.01.01 ~ 2021.06.30
# 21      1,888,526,839      157  제 24 기반기  2021.01.01 ~ 2021.06.30
# 22    -38,935,759,418   -3,245  제 24 기반기  2021.01.01 ~ 2021.06.30
# 23    -29,300,490,022   -2,442  제 24 기반기  2021.01.01 ~ 2021.06.30
#
#                  전기금액             당기누적금액           전기누적금액
# 0   1,619,673,745,793                NaN              NaN
# 1   1,781,356,734,028                NaN              NaN
# 2   3,401,030,479,821                NaN              NaN
# 3     967,353,222,621                NaN              NaN
# 4     736,305,983,792                NaN              NaN
# 5   1,703,659,206,413                NaN              NaN
# 6   1,697,371,273,408                NaN              NaN
# 7     309,980,762,819  1,912,431,010,462  572,586,483,671
# 8      29,685,383,738    223,804,845,809   49,160,170,291
# 9      23,356,629,809    161,908,062,654   44,606,393,645
# 10    566,833,503,212    145,203,671,550  577,911,077,887
# 11    177,020,398,734                NaN              NaN
# 12    623,330,894,263                NaN              NaN
# 13    800,351,292,997                NaN              NaN
# 14     28,236,680,327                NaN              NaN
# 15    207,321,136,940                NaN              NaN
# 16    235,557,817,267                NaN              NaN
# 17     11,987,836,000                NaN              NaN
# 18    453,961,804,789                NaN              NaN
# 19    564,793,475,730                NaN              NaN
# 20      2,067,820,000     20,270,151,210    8,877,351,550
# 21     -1,085,657,894     11,166,214,914    2,767,457,433
# 22     28,569,944,696    -29,970,093,963   61,529,968,655
# 23    579,062,835,551    -20,894,730,595  605,526,846,582
#    사업 연도      회사코드  재무제표명         계정명        당기명                     당기일자  \
# 13  152,917,096,233   12,743   제 22 기말            2021.12.31 현재
# 14   23,196,211,724    1,933   제 22 기말            2021.12.31 현재
# 15    1,523,899,091      126   제 22 기말            2021.12.31 현재
# 16   24,720,110,815    2,060   제 22 기말            2021.12.31 현재
# 17    4,898,400,000      408   제 22 기말            2021.12.31 현재
# 18  112,090,756,551    9,340   제 22 기말            2021.12.31 현재
# 19  128,196,985,418   10,683   제 22 기말            2021.12.31 현재
# 20   17,881,112,154    1,490  제 22 기반기  2021.01.01 ~ 2021.06.30
# 21    1,918,785,034      159  제 22 기반기  2021.01.01 ~ 2021.06.30
# 22    2,841,809,094      236  제 22 기반기  2021.01.01 ~ 2021.06.30
# 23    2,500,258,751      208  제 22 기반기  2021.01.01 ~ 2021.06.30
#
#                전기금액          당기누적금액          전기누적금액
# 0    97,313,955,633             NaN             NaN
# 1    62,109,239,996             NaN             NaN
# 2   159,423,195,629             NaN             NaN
# 3    29,148,766,842             NaN             NaN
# 4     2,301,631,410             NaN             NaN
# 5    31,450,398,252             NaN             NaN
# 6   127,972,797,377             NaN             NaN
# 7    13,691,770,630  28,992,373,456  25,575,417,641
# 8      -160,829,232    -349,601,405    -173,401,734
# 9     1,459,180,271     593,432,000   1,972,940,398
# 10      220,764,065   1,260,665,815   1,015,087,400
# 11   97,011,294,540             NaN             NaN
# 12   62,092,992,335             NaN             NaN
# 13  159,104,286,875             NaN             NaN
# 14   29,124,060,182             NaN             NaN
# 15    2,369,105,326             NaN             NaN
# 16   31,493,165,508             NaN             NaN
# 17    4,898,400,000             NaN             NaN
# 18  111,405,442,500             NaN             NaN
# 19  127,611,121,367             NaN             NaN
# 20   13,691,770,630  28,992,373,456  25,575,417,641
# 21     -191,543,937    -250,882,444    -230,259,587
# 22    1,429,399,001     694,585,957   1,916,921,415
# 23      190,982,795   1,339,565,901     959,068,417
#    사업 연도      회사코드  재무제표명         계정명         당기명                     당기일자  \
# 0   2022  00536541  재무상태표        유동자산  제 25 기1분기말            2022.03.31 현재
# 1   2022  00536541  재무상태표       비유동자산  제 25 기1분기말            2022.03.31 현재
# 2   2022  00536541  재무상태표        자산총계  제 25 기1분기말            2022.03.31 현재
# 3   2022  00536541  재무상태표        유동부채  제 25 기1분기말            2022.03.31 현재
# 4   2022  00536541  재무상태표       비유동부채  제 25 기1분기말            2022.03.31 현재
# 5   2022  00536541  재무상태표        부채총계  제 25 기1분기말            2022.03.31 현재
# 6   2022  00536541  재무상태표        자본총계  제 25 기1분기말            2022.03.31 현재
# 7   2022  00536541  손익계산서         매출액   제 25 기1분기  2022.01.01 ~ 2022.03.31
# 8   2022  00536541  손익계산서        영업이익   제 25 기1분기  2022.01.01 ~ 2022.03.31
# 9   2022  00536541  손익계산서  법인세차감전 순이익   제 25 기1분기  2022.01.01 ~ 2022.03.31
# 10  2022  00536541  손익계산서       당기순이익   제 25 기1분기  2022.01.01 ~ 2022.03.31
# 11  2022  00536541  재무상태표        유동자산  제 25 기1분기말            2022.03.31 현재
# 12  2022  00536541  재무상태표       비유동자산  제 25 기1분기말            2022.03.31 현재
# 13  2022  00536541  재무상태표        자산총계  제 25 기1분기말            2022.03.31 현재
# 14  2022  00536541  재무상태표        유동부채  제 25 기1분기말            2022.03.31 현재
# 15  2022  00536541  재무상태표       비유동부채  제 25 기1분기말            2022.03.31 현재
# 16  2022  00536541  재무상태표        부채총계  제 25 기1분기말            2022.03.31 현재
# 17  2022  00536541  재무상태표         자본금  제 25 기1분기말            2022.03.31 현재
# 18  2022  00536541  재무상태표       이익잉여금  제 25 기1분기말            2022.03.31 현재
# 19  2022  00536541  재무상태표        자본총계  제 25 기1분기말            2022.03.31 현재
# 20  2022  00536541  손익계산서         매출액   제 25 기1분기  2022.01.01 ~ 2022.03.31
# 21  2022  00536541  손익계산서        영업이익   제 25 기1분기  2022.01.01 ~ 2022.03.31
# 22  2022  00536541  손익계산서  법인세차감전 순이익   제 25 기1분기  2022.01.01 ~ 2022.03.31
# 23  2022  00536541  손익계산서       당기순이익   제 25 기1분기  2022.01.01 ~ 2022.03.31
#
#                  당기금액 월평균(백만원)        전기명                     전기일자  \
# 0   2,003,202,091,350  166,933    제 24 기말            2021.12.31 현재
# 1   1,889,650,793,271  157,470    제 24 기말            2021.12.31 현재
# 2   3,892,852,884,621  324,404    제 24 기말            2021.12.31 현재
# 3   1,350,027,944,247  112,502    제 24 기말            2021.12.31 현재
# 4     814,520,502,031   67,876    제 24 기말            2021.12.31 현재
# 5   2,164,548,446,278  180,379    제 24 기말            2021.12.31 현재
# 6   1,728,304,438,343  144,025    제 24 기말            2021.12.31 현재
# 7     680,627,292,254   56,718  제 24 기1분기  2021.01.01 ~ 2021.03.31
# 8      53,894,068,783    4,491  제 24 기1분기  2021.01.01 ~ 2021.03.31
# 9      49,740,332,819    4,145  제 24 기1분기  2021.01.01 ~ 2021.03.31
# 10     42,767,727,360    3,563  제 24 기1분기  2021.01.01 ~ 2021.03.31
# 11    171,023,720,026   14,251    제 24 기말            2021.12.31 현재
# 12    628,856,444,640   52,404    제 24 기말            2021.12.31 현재
# 13    799,880,164,666   66,656    제 24 기말            2021.12.31 현재
# 14     33,693,329,924    2,807    제 24 기말            2021.12.31 현재
# 15    207,270,418,931   17,272    제 24 기말            2021.12.31 현재
# 16    240,963,748,855   20,080    제 24 기말            2021.12.31 현재
# 17     11,987,836,000      998    제 24 기말            2021.12.31 현재
# 18    451,913,091,336   37,659    제 24 기말            2021.12.31 현재
# 19    558,916,415,811   46,576    제 24 기말            2021.12.31 현재
# 20     14,038,438,210    1,169  제 24 기1분기  2021.01.01 ~ 2021.03.31
# 21      9,277,688,075      773  제 24 기1분기  2021.01.01 ~ 2021.03.31
# 22      8,965,665,455      747  제 24 기1분기  2021.01.01 ~ 2021.03.31
# 23      8,405,759,427      700  제 24 기1분기  2021.01.01 ~ 2021.03.31
#
#                  전기금액           당기누적금액           전기누적금액
# 0   1,616,056,572,888              NaN              NaN
# 1   1,784,901,514,108              NaN              NaN
# 2   3,400,958,086,996              NaN              NaN
# 3     967,353,222,621              NaN              NaN
# 4     736,305,983,792              NaN              NaN
# 5   1,703,659,206,413              NaN              NaN
# 6   1,697,298,880,583              NaN              NaN
# 7     262,605,720,852  680,627,292,254  262,605,720,852
# 8      19,474,786,553   53,894,068,783   19,474,786,553
# 9      21,249,763,836   49,740,332,819   21,249,763,836
# 10     11,077,574,675   42,767,727,360   11,077,574,675
# 11    177,020,398,734              NaN              NaN
# 12    623,330,894,263              NaN              NaN
# 13    800,351,292,997              NaN              NaN
# 14     28,236,680,327              NaN              NaN
# 15    207,321,136,940              NaN              NaN
# 16    235,557,817,267              NaN              NaN
# 17     11,987,836,000              NaN              NaN
# 18    453,961,804,789              NaN              NaN
# 19    564,793,475,730              NaN              NaN
# 20      6,809,531,550   14,038,438,210    6,809,531,550
# 21      3,853,115,327    9,277,688,075    3,853,115,327
# 22     32,960,023,959    8,965,665,455   32,960,023,959
# 23     26,464,011,031    8,405,759,427   26,464,011,031
#    사업 연도      회사코드  재무제표명         계정명         당기명                     당기일자  \
# 0   2022  00360674  재무상태표        유동자산  제 23 기1분기말            2022.03.31 현재
# 1   2022  00360674  재무상태표       비유동자산  제 23 기1분기말            2022.03.31 현재
# 2   2022  00360674  재무상태표        자산총계  제 23 기1분기말            2022.03.31 현재
# 3   2022  00360674  재무상태표        유동부채  제 23 기1분기말            2022.03.31 현재
# 4   2022  00360674  재무상태표       비유동부채  제 23 기1분기말            2022.03.31 현재
# 5   2022  00360674  재무상태표        부채총계  제 23 기1분기말            2022.03.31 현재
# 6   2022  00360674  재무상태표        자본총계  제 23 기1분기말            2022.03.31 현재
# 7   2022  00360674  손익계산서         매출액   제 23 기1분기  2022.01.01 ~ 2022.03.31
# 8   2022  00360674  손익계산서        영업이익   제 23 기1분기  2022.01.01 ~ 2022.03.31
# 9   2022  00360674  손익계산서  법인세차감전 순이익   제 23 기1분기  2022.01.01 ~ 2022.03.31
# 10  2022  00360674  손익계산서       당기순이익   제 23 기1분기  2022.01.01 ~ 2022.03.31
# 11  2022  00360674  재무상태표        유동자산  제 23 기1분기말            2022.03.31 현재
# 12  2022  00360674  재무상태표       비유동자산  제 23 기1분기말            2022.03.31 현재
# 13  2022  00360674  재무상태표        자산총계  제 23 기1분기말            2022.03.31 현재
# 14  2022  00360674  재무상태표        유동부채  제 23 기1분기말            2022.03.31 현재
# 15  2022  00360674  재무상태표       비유동부채  제 23 기1분기말            2022.03.31 현재
# 16  2022  00360674  재무상태표        부채총계  제 23 기1분기말            2022.03.31 현재
# 17  2022  00360674  재무상태표         자본금  제 23 기1분기말            2022.03.31 현재
# 18  2022  00360674  재무상태표       이익잉여금  제 23 기1분기말            2022.03.31 현재
# 19  2022  00360674  재무상태표        자본총계  제 23 기1분기말            2022.03.31 현재
# 20  2022  00360674  손익계산서         매출액   제 23 기1분기  2022.01.01 ~ 2022.03.31
# 21  2022  00360674  손익계산서        영업이익   제 23 기1분기  2022.01.01 ~ 2022.03.31
# 22  2022  00360674  손익계산서  법인세차감전 순이익   제 23 기1분기  2022.01.01 ~ 2022.03.31
# 23  2022  00360674  손익계산서       당기순이익   제 23 기1분기  2022.01.01 ~ 2022.03.31
#
#                당기금액 월평균(백만원)        전기명                     전기일자  \
# 0    90,775,206,646    7,564    제 22 기말            2021.12.31 현재
# 1    63,331,814,414    5,277    제 22 기말            2021.12.31 현재
# 2   154,107,021,060   12,842    제 22 기말            2021.12.31 현재
# 3    25,346,236,950    2,112    제 22 기말            2021.12.31 현재
# 4     2,663,571,831      221    제 22 기말            2021.12.31 현재
# 5    28,009,808,781    2,334    제 22 기말            2021.12.31 현재
# 6   126,097,212,279   10,508    제 22 기말            2021.12.31 현재
# 7    11,116,861,302      926  제 22 기1분기  2021.01.01 ~ 2021.03.31
# 8    -2,230,368,636     -186  제 22 기1분기  2021.01.01 ~ 2021.03.31
# 9    -2,207,863,535     -184  제 22 기1분기  2021.01.01 ~ 2021.03.31
# 10   -1,221,333,248     -102  제 22 기1분기  2021.01.01 ~ 2021.03.31
# 11   90,541,524,701    7,545    제 22 기말            2021.12.31 현재
# 12   63,336,104,316    5,278    제 22 기말            2021.12.31 현재
# 13  153,877,629,017   12,823    제 22 기말            2021.12.31 현재
# 14   25,338,453,270    2,111    제 22 기말            2021.12.31 현재
# 15    2,742,999,080      228    제 22 기말            2021.12.31 현재
# 16   28,081,452,350    2,340    제 22 기말            2021.12.31 현재
# 17    4,898,400,000      408    제 22 기말            2021.12.31 현재
# 18  109,590,497,800    9,132    제 22 기말            2021.12.31 현재
# 19  125,796,176,667   10,483    제 22 기말            2021.12.31 현재
# 20   11,111,261,302      925  제 22 기1분기  2021.01.01 ~ 2021.03.31
# 21   -2,169,667,478     -181  제 22 기1분기  2021.01.01 ~ 2021.03.31
# 22   -2,147,223,137     -179  제 22 기1분기  2021.01.01 ~ 2021.03.31
# 23   -1,160,692,850      -97  제 22 기1분기  2021.01.01 ~ 2021.03.31
#
#                전기금액          당기누적금액          전기누적금액
# 0    97,313,955,633             NaN             NaN
# 1    62,109,239,996             NaN             NaN
# 2   159,423,195,629             NaN             NaN
# 3    29,148,766,842             NaN             NaN
# 4     2,301,631,410             NaN             NaN
# 5    31,450,398,252             NaN             NaN
# 6   127,972,797,377             NaN             NaN
# 7    11,883,647,011  11,116,861,302  11,883,647,011
# 8       -12,572,502  -2,230,368,636     -12,572,502
# 9       513,760,127  -2,207,863,535     513,760,127
# 10      794,323,335  -1,221,333,248     794,323,335
# 11   97,011,294,540             NaN             NaN
# 12   62,092,992,335             NaN             NaN
# 13  159,104,286,875             NaN             NaN
# 14   29,124,060,182             NaN             NaN
# 15    2,369,105,326             NaN             NaN
# 16   31,493,165,508             NaN             NaN
# 17    4,898,400,000             NaN             NaN
# 18  111,405,442,500             NaN             NaN
# 19  127,611,121,367             NaN             NaN
# 20   11,883,647,011  11,111,261,302  11,883,647,011
# 21      -38,715,650  -2,169,667,478     -38,715,650
# 22      487,522,414  -2,147,223,137     487,522,414
# 23      768,085,622  -1,160,692,850     768,085,622
#    사업 연도      회사코드  재무제표명         계정명         당기명                     당기일자  \
# 0   2022  00536541  재무상태표        유동자산  제 25 기3분기말            2022.09.30 현재
# 1   2022  00536541  재무상태표       비유동자산  제 25 기3분기말            2022.09.30 현재
# 2   2022  00536541  재무상태표        자산총계  제 25 기3분기말            2022.09.30 현재
# 3   2022  00536541  재무상태표        유동부채  제 25 기3분기말            2022.09.30 현재
# 4   2022  00536541  재무상태표       비유동부채  제 25 기3분기말            2022.09.30 현재
# 5   2022  00536541  재무상태표        부채총계  제 25 기3분기말            2022.09.30 현재
# 6   2022  00536541  재무상태표        자본총계  제 25 기3분기말            2022.09.30 현재
# 7   2022  00536541  손익계산서         매출액   제 25 기3분기  2022.01.01 ~ 2022.09.30
# 8   2022  00536541  손익계산서        영업이익   제 25 기3분기  2022.01.01 ~ 2022.09.30
# 9   2022  00536541  손익계산서  법인세차감전 순이익   제 25 기3분기  2022.01.01 ~ 2022.09.30
# 10  2022  00536541  손익계산서       당기순이익   제 25 기3분기  2022.01.01 ~ 2022.09.30
# 11  2022  00536541  재무상태표        유동자산  제 25 기3분기말            2022.09.30 현재
# 12  2022  00536541  재무상태표       비유동자산  제 25 기3분기말            2022.09.30 현재
# 13  2022  00536541  재무상태표        자산총계  제 25 기3분기말            2022.09.30 현재
# 14  2022  00536541  재무상태표        유동부채  제 25 기3분기말            2022.09.30 현재
# 15  2022  00536541  재무상태표       비유동부채  제 25 기3분기말            2022.09.30 현재
# 16  2022  00536541  재무상태표        부채총계  제 25 기3분기말            2022.09.30 현재
# 17  2022  00536541  재무상태표         자본금  제 25 기3분기말            2022.09.30 현재
# 18  2022  00536541  재무상태표       이익잉여금  제 25 기3분기말            2022.09.30 현재
# 19  2022  00536541  재무상태표        자본총계  제 25 기3분기말            2022.09.30 현재
# 20  2022  00536541  손익계산서        영업이익   제 25 기3분기  2022.01.01 ~ 2022.09.30
# 21  2022  00536541  손익계산서  법인세차감전 순이익   제 25 기3분기  2022.01.01 ~ 2022.09.30
# 22  2022  00536541  손익계산서       당기순이익   제 25 기3분기  2022.01.01 ~ 2022.09.30
#
#                  당기금액 월평균(백만원)        전기명                     전기일자  \
# 0   3,288,926,068,065  274,077    제 24 기말            2021.12.31 현재
# 1   2,257,175,402,393  188,097    제 24 기말            2021.12.31 현재
# 2   5,546,101,470,458  462,175    제 24 기말            2021.12.31 현재
# 3   2,167,268,406,427  180,605    제 24 기말            2021.12.31 현재
# 4     799,217,020,401   66,601    제 24 기말            2021.12.31 현재
# 5   2,966,485,426,828  247,207    제 24 기말            2021.12.31 현재
# 6   2,579,616,043,630  214,968    제 24 기말            2021.12.31 현재
# 7   1,631,738,986,282  135,978  제 24 기3분기  2021.01.01 ~ 2021.09.30
# 8     211,406,384,956   17,617  제 24 기3분기  2021.01.01 ~ 2021.09.30
# 9     213,638,457,842   17,803  제 24 기3분기  2021.01.01 ~ 2021.09.30
# 10    174,701,856,048   14,558  제 24 기3분기  2021.01.01 ~ 2021.09.30
# 11     47,406,761,610    3,950    제 24 기말            2021.12.31 현재
# 12    927,359,326,726   77,279    제 24 기말            2021.12.31 현재
# 13    974,766,088,336   81,230    제 24 기말            2021.12.31 현재
# 14    143,513,423,519   11,959    제 24 기말            2021.12.31 현재
# 15    184,068,653,856   15,339    제 24 기말            2021.12.31 현재
# 16    327,582,077,375   27,298    제 24 기말            2021.12.31 현재
# 17     12,525,752,000    1,043    제 24 기말            2021.12.31 현재
# 18    493,028,315,079   41,085    제 24 기말            2021.12.31 현재
# 19    647,184,010,961   53,932    제 24 기말            2021.12.31 현재
# 20      4,179,831,224      348  제 24 기3분기  2021.01.01 ~ 2021.09.30
# 21     43,945,736,390    3,662  제 24 기3분기  2021.01.01 ~ 2021.09.30
# 22     35,628,685,001    2,969  제 24 기3분기  2021.01.01 ~ 2021.09.30
#
#                  전기금액             당기누적금액           전기누적금액
# 0   1,619,673,745,793                NaN              NaN
# 1   1,781,356,734,028                NaN              NaN
# 2   3,401,030,479,821                NaN              NaN
# 3     967,353,222,621                NaN              NaN
# 4     736,305,983,792                NaN              NaN
# 5   1,703,659,206,413                NaN              NaN
# 6   1,697,371,273,408                NaN              NaN
# 7     408,452,511,989  3,544,169,996,744  981,066,406,660
# 8      46,115,477,267    435,211,230,765   95,303,058,558
# 9      36,372,612,799    375,546,520,496   80,979,006,444
# 10     39,600,000,320    319,905,527,598  617,511,078,207
# 11    177,020,398,734                NaN              NaN
# 12    623,330,894,263                NaN              NaN
# 13    800,351,292,997                NaN              NaN
# 14     28,236,680,327                NaN              NaN
# 15    207,321,136,940                NaN              NaN
# 16    235,557,817,267                NaN              NaN
# 17     11,987,836,000                NaN              NaN
# 18    453,961,804,789                NaN              NaN
# 19    564,793,475,730                NaN              NaN
# 20       -742,176,622     15,346,046,138    2,025,280,811
# 21       -504,768,015     13,975,642,427   61,025,200,640
# 22       -196,696,176     14,733,954,406  605,330,150,406
#    사업 연도      회사코드  재무제표명         계정명         당기명                     당기일자  \
# 0   2022  00360674  재무상태표        유동자산  제 23 기3분기말            2022.09.30 현재
# 1   2022  00360674  재무상태표       비유동자산  제 23 기3분기말            2022.09.30 현재
# 2   2022  00360674  재무상태표        자산총계  제 23 기3분기말            2022.09.30 현재
# 3   2022  00360674  재무상태표        유동부채  제 23 기3분기말            2022.09.30 현재
# 4   2022  00360674  재무상태표       비유동부채  제 23 기3분기말            2022.09.30 현재
# 5   2022  00360674  재무상태표        부채총계  제 23 기3분기말            2022.09.30 현재
# 6   2022  00360674  재무상태표        자본총계  제 23 기3분기말            2022.09.30 현재
# 7   2022  00360674  손익계산서         매출액   제 23 기3분기  2022.01.01 ~ 2022.09.30
# 8   2022  00360674  손익계산서        영업이익   제 23 기3분기  2022.01.01 ~ 2022.09.30
# 9   2022  00360674  손익계산서  법인세차감전 순이익   제 23 기3분기  2022.01.01 ~ 2022.09.30
# 10  2022  00360674  손익계산서       당기순이익   제 23 기3분기  2022.01.01 ~ 2022.09.30
# 11  2022  00360674  재무상태표        유동자산  제 23 기3분기말            2022.09.30 현재
# 12  2022  00360674  재무상태표       비유동자산  제 23 기3분기말            2022.09.30 현재
# 13  2022  00360674  재무상태표        자산총계  제 23 기3분기말            2022.09.30 현재
# 14  2022  00360674  재무상태표        유동부채  제 23 기3분기말            2022.09.30 현재
# 15  2022  00360674  재무상태표       비유동부채  제 23 기3분기말            2022.09.30 현재
# 16  2022  00360674  재무상태표        부채총계  제 23 기3분기말            2022.09.30 현재
# 17  2022  00360674  재무상태표         자본금  제 23 기3분기말            2022.09.30 현재
# 18  2022  00360674  재무상태표       이익잉여금  제 23 기3분기말            2022.09.30 현재
# 19  2022  00360674  재무상태표        자본총계  제 23 기3분기말            2022.09.30 현재
# 20  2022  00360674  손익계산서         매출액   제 23 기3분기  2022.01.01 ~ 2022.09.30
# 21  2022  00360674  손익계산서        영업이익   제 23 기3분기  2022.01.01 ~ 2022.09.30
# 22  2022  00360674  손익계산서  법인세차감전 순이익   제 23 기3분기  2022.01.01 ~ 2022.09.30
# 23  2022  00360674  손익계산서       당기순이익   제 23 기3분기  2022.01.01 ~ 2022.09.30
#
#                당기금액 월평균(백만원)        전기명                     전기일자  \
# 0    96,574,841,922    8,047    제 22 기말            2021.12.31 현재
# 1    56,571,967,670    4,714    제 22 기말            2021.12.31 현재
# 2   153,146,809,592   12,762    제 22 기말            2021.12.31 현재
# 3    20,630,969,251    1,719    제 22 기말            2021.12.31 현재
# 4     1,523,085,089      126    제 22 기말            2021.12.31 현재
# 5    22,154,054,340    1,846    제 22 기말            2021.12.31 현재
# 6   130,992,755,252   10,916    제 22 기말            2021.12.31 현재
# 7    22,371,085,625    1,864  제 22 기3분기  2021.01.01 ~ 2021.09.30
# 8      -818,497,976      -69  제 22 기3분기  2021.01.01 ~ 2021.09.30
# 9     2,821,345,125      235  제 22 기3분기  2021.01.01 ~ 2021.09.30
# 10    2,667,413,103      222  제 22 기3분기  2021.01.01 ~ 2021.09.30
# 11   96,498,620,114    8,041    제 22 기말            2021.12.31 현재
# 12   56,455,258,970    4,704    제 22 기말            2021.12.31 현재
# 13  152,953,879,084   12,746    제 22 기말            2021.12.31 현재
# 14   20,628,336,121    1,719    제 22 기말            2021.12.31 현재
# 15    1,436,532,797      119    제 22 기말            2021.12.31 현재
# 16   22,064,868,918    1,838    제 22 기말            2021.12.31 현재
# 17    4,898,400,000      408    제 22 기말            2021.12.31 현재
# 18  114,787,461,299    9,565    제 22 기말            2021.12.31 현재
# 19  130,889,010,166   10,907    제 22 기말            2021.12.31 현재
# 20   22,382,285,625    1,865  제 22 기3분기  2021.01.01 ~ 2021.09.30
# 21     -775,374,732      -65  제 22 기3분기  2021.01.01 ~ 2021.09.30
# 22    2,858,898,516      238  제 22 기3분기  2021.01.01 ~ 2021.09.30
# 23    2,696,704,748      224  제 22 기3분기  2021.01.01 ~ 2021.09.30
#
#                전기금액          당기누적금액          전기누적금액
# 0    97,313,955,633             NaN             NaN
# 1    62,109,239,996             NaN             NaN
# 2   159,423,195,629             NaN             NaN
# 3    29,148,766,842             NaN             NaN
# 4     2,301,631,410             NaN             NaN
# 5    31,450,398,252             NaN             NaN
# 6   127,972,797,377             NaN             NaN
# 7    17,602,947,992  51,374,659,081  43,178,365,633
# 8      -948,743,035  -1,171,099,381  -1,122,144,769
# 9      -196,886,572   3,414,777,125   1,776,053,826
# 10     -199,495,161   3,928,078,918     815,592,239
# 11   97,011,294,540             NaN             NaN
# 12   62,092,992,335             NaN             NaN
# 13  159,104,286,875             NaN             NaN
# 14   29,124,060,182             NaN             NaN
# 15    2,369,105,326             NaN             NaN
# 16   31,493,165,508             NaN             NaN
# 17    4,898,400,000             NaN             NaN
# 18  111,405,442,500             NaN             NaN
# 19  127,611,121,367             NaN             NaN
# 20   17,602,947,992  51,374,659,081  43,178,365,633
# 21     -966,154,189  -1,026,257,176  -1,196,413,776
# 22     -213,162,518   3,553,484,473   1,703,758,897
# 23     -215,771,107   4,036,270,649     743,297,310
#    사업 연도      회사코드  재무제표명         계정명        당기명                     당기일자  \
# 0   2023  00536541  재무상태표        유동자산  제 26 기반기말            2023.06.30 현재
# 1   2023  00536541  재무상태표       비유동자산  제 26 기반기말            2023.06.30 현재
# 2   2023  00536541  재무상태표        자산총계  제 26 기반기말            2023.06.30 현재
# 3   2023  00536541  재무상태표        유동부채  제 26 기반기말            2023.06.30 현재
# 4   2023  00536541  재무상태표       비유동부채  제 26 기반기말            2023.06.30 현재
# 5   2023  00536541  재무상태표        부채총계  제 26 기반기말            2023.06.30 현재
# 6   2023  00536541  재무상태표         자본금  제 26 기반기말            2023.06.30 현재
# 7   2023  00536541  재무상태표       이익잉여금  제 26 기반기말            2023.06.30 현재
# 8   2023  00536541  재무상태표        자본총계  제 26 기반기말            2023.06.30 현재
# 9   2023  00536541  손익계산서         매출액   제 26 기반기  2023.01.01 ~ 2023.06.30
# 10  2023  00536541  손익계산서        영업이익   제 26 기반기  2023.01.01 ~ 2023.06.30
# 11  2023  00536541  손익계산서  법인세차감전 순이익   제 26 기반기  2023.01.01 ~ 2023.06.30
# 12  2023  00536541  손익계산서       당기순이익   제 26 기반기  2023.01.01 ~ 2023.06.30
# 13  2023  00536541  재무상태표        유동자산  제 26 기반기말            2023.06.30 현재
# 14  2023  00536541  재무상태표       비유동자산  제 26 기반기말            2023.06.30 현재
# 15  2023  00536541  재무상태표        자산총계  제 26 기반기말            2023.06.30 현재
# 16  2023  00536541  재무상태표        유동부채  제 26 기반기말            2023.06.30 현재
# 17  2023  00536541  재무상태표       비유동부채  제 26 기반기말            2023.06.30 현재
# 18  2023  00536541  재무상태표        부채총계  제 26 기반기말            2023.06.30 현재
# 19  2023  00536541  재무상태표         자본금  제 26 기반기말            2023.06.30 현재
# 20  2023  00536541  재무상태표       이익잉여금  제 26 기반기말            2023.06.30 현재
# 21  2023  00536541  재무상태표        자본총계  제 26 기반기말            2023.06.30 현재
# 22  2023  00536541  손익계산서        영업이익   제 26 기반기  2023.01.01 ~ 2023.06.30
# 23  2023  00536541  손익계산서  법인세차감전 순이익   제 26 기반기  2023.01.01 ~ 2023.06.30
# 24  2023  00536541  손익계산서       당기순이익   제 26 기반기  2023.01.01 ~ 2023.06.30
#
#                  당기금액 월평균(백만원)       전기명                     전기일자  \
# 0   3,753,187,572,248  312,765   제 25 기말            2022.12.31 현재
# 1   2,735,130,501,084  227,927   제 25 기말            2022.12.31 현재
# 2   6,488,318,073,332  540,693   제 25 기말            2022.12.31 현재
# 3   2,989,771,566,716  249,147   제 25 기말            2022.12.31 현재
# 4     690,883,934,975   57,573   제 25 기말            2022.12.31 현재
# 5   3,680,655,501,691  306,721   제 25 기말            2022.12.31 현재
# 6      13,313,835,500    1,109   제 25 기말            2022.12.31 현재
# 7     507,402,011,665   42,283   제 25 기말            2022.12.31 현재
# 8   2,807,662,571,641  233,971   제 25 기말            2022.12.31 현재
# 9   2,017,183,598,478  168,098  제 25 기반기  2022.01.01 ~ 2022.06.30
# 10    170,264,591,430   14,188  제 25 기반기  2022.01.01 ~ 2022.06.30
# 11   -272,161,195,106  -22,681  제 25 기반기  2022.01.01 ~ 2022.06.30
# 12   -217,229,575,867  -18,103  제 25 기반기  2022.01.01 ~ 2022.06.30
# 13    195,940,483,391   16,328   제 25 기말            2022.12.31 현재
# 14    844,125,039,200   70,343   제 25 기말            2022.12.31 현재
# 15  1,040,065,522,591   86,672   제 25 기말            2022.12.31 현재
# 16    242,300,556,637   20,191   제 25 기말            2022.12.31 현재
# 17     68,088,622,927    5,674   제 25 기말            2022.12.31 현재
# 18    310,389,179,564   25,865   제 25 기말            2022.12.31 현재
# 19     13,313,835,500    1,109   제 25 기말            2022.12.31 현재
# 20    564,213,544,543   47,017   제 25 기말            2022.12.31 현재
# 21    729,676,343,027   60,806   제 25 기말            2022.12.31 현재
# 22    204,642,788,010   17,053  제 25 기반기  2022.01.01 ~ 2022.06.30
# 23   -216,505,067,364  -18,043  제 25 기반기  2022.01.01 ~ 2022.06.30
# 24   -131,978,208,359  -10,999  제 25 기반기  2022.01.01 ~ 2022.06.30
#
#                  전기금액             당기누적금액             전기누적금액
# 0   3,162,551,112,304                NaN                NaN
# 1   2,183,231,490,740                NaN                NaN
# 2   5,345,782,603,044                NaN                NaN
# 3   2,082,665,018,806                NaN                NaN
# 4     741,336,930,529                NaN                NaN
# 5   2,824,001,949,335                NaN                NaN
# 6      12,628,762,500                NaN                NaN
# 7     424,859,393,453                NaN                NaN
# 8   2,521,780,653,709                NaN                NaN
# 9   1,231,803,718,208  4,081,596,466,414  1,912,431,010,462
# 10    169,910,777,026    352,633,347,192    223,804,845,809
# 11    112,167,729,835    267,466,413,471    161,908,062,654
# 12    102,435,944,190    211,248,809,023    145,203,671,550
# 13     85,518,930,923                NaN                NaN
# 14    766,097,598,715                NaN                NaN
# 15    851,616,529,638                NaN                NaN
# 16    131,486,088,494                NaN                NaN
# 17    161,898,786,837                NaN                NaN
# 18    293,384,875,331                NaN                NaN
# 19     12,628,762,500                NaN                NaN
# 20    391,212,235,688                NaN                NaN
# 21    558,231,654,307                NaN                NaN
# 22      1,888,526,839    224,989,795,516     11,166,214,914
# 23    -38,935,759,418    179,221,625,903    -29,970,093,963
# 24    -29,300,490,022    185,884,808,855    -20,894,730,595
#    사업 연도      회사코드  재무제표명         계정명        당기명                     당기일자  \
# 0   2023  00360674  재무상태표        유동자산  제 24 기반기말            2023.06.30 현재
# 1   2023  00360674  재무상태표       비유동자산  제 24 기반기말            2023.06.30 현재
# 15    1,048,907,424       87   제 23 기말            2022.12.31 현재
# 16   25,322,287,345    2,110   제 23 기말            2022.12.31 현재
# 17    4,898,400,000      408   제 23 기말            2022.12.31 현재
# 18  108,533,063,984    9,044   제 23 기말            2022.12.31 현재
# 19  124,614,517,851   10,384   제 23 기말            2022.12.31 현재
# 20   16,681,329,264    1,390  제 23 기반기  2022.01.01 ~ 2022.06.30
# 21   -1,907,189,315     -159  제 23 기반기  2022.01.01 ~ 2022.06.30
# 22   -5,119,925,691     -427  제 23 기반기  2022.01.01 ~ 2022.06.30
# 23   -6,040,325,732     -504  제 23 기반기  2022.01.01 ~ 2022.06.30
#
#                전기금액          당기누적금액          전기누적금액
# 0   111,476,875,669             NaN             NaN
# 1    57,417,494,160             NaN             NaN
# 2   168,894,369,829             NaN             NaN
# 3    36,001,100,333             NaN             NaN
# 4     1,192,324,830             NaN             NaN
# 5    37,193,425,163             NaN             NaN
# 6   131,700,944,666             NaN             NaN
# 7    17,869,912,154  27,650,079,397  28,992,373,456
# 8     1,880,767,231  -4,078,887,463    -349,601,405
# 9     2,801,295,535  -6,987,499,623     593,432,000
# 10    2,481,999,063  -6,528,212,028   1,260,665,815
# 11  111,420,814,832             NaN             NaN
# 12   57,296,484,116             NaN             NaN
# 13  168,717,298,948             NaN             NaN
# 14   35,995,914,083             NaN             NaN
# 15    1,107,084,117             NaN             NaN
# 16   37,102,998,200             NaN             NaN
# 17    4,898,400,000             NaN             NaN
# 18  115,526,131,881             NaN             NaN
# 19  131,614,300,748             NaN             NaN
# 20   17,881,112,154  27,650,079,397  28,992,373,456
# 21    1,918,785,034  -4,076,255,271    -250,882,444
# 22    2,841,809,094  -6,983,994,155     694,585,957
# 23    2,500,258,751  -6,525,745,147   1,339,565,901
#    사업 연도      회사코드  재무제표명         계정명         당기명                     당기일자  \
# 0   2023  00536541  재무상태표        유동자산  제 26 기1분기말            2023.03.31 현재
# 1   2023  00536541  재무상태표       비유동자산  제 26 기1분기말            2023.03.31 현재
# 2   2023  00536541  재무상태표        자산총계  제 26 기1분기말            2023.03.31 현재
# 3   2023  00536541  재무상태표        유동부채  제 26 기1분기말            2023.03.31 현재
# 4   2023  00536541  재무상태표       비유동부채  제 26 기1분기말            2023.03.31 현재
# 5   2023  00536541  재무상태표        부채총계  제 26 기1분기말            2023.03.31 현재
# 6   2023  00536541  재무상태표         자본금  제 26 기1분기말            2023.03.31 현재
# 7   2023  00536541  재무상태표       이익잉여금  제 26 기1분기말            2023.03.31 현재
# 8   2023  00536541  재무상태표        자본총계  제 26 기1분기말            2023.03.31 현재
# 9   2023  00536541  손익계산서         매출액   제 26 기1분기  2023.01.01 ~ 2023.03.31
# 10  2023  00536541  손익계산서        영업이익   제 26 기1분기  2023.01.01 ~ 2023.03.31
# 11  2023  00536541  손익계산서  법인세차감전 순이익   제 26 기1분기  2023.01.01 ~ 2023.03.31
# 12  2023  00536541  손익계산서       당기순이익   제 26 기1분기  2023.01.01 ~ 2023.03.31
# 13  2023  00536541  재무상태표        유동자산  제 26 기1분기말            2023.03.31 현재
# 14  2023  00536541  재무상태표       비유동자산  제 26 기1분기말            2023.03.31 현재
# 15  2023  00536541  재무상태표        자산총계  제 26 기1분기말            2023.03.31 현재
# 16  2023  00536541  재무상태표        유동부채  제 26 기1분기말            2023.03.31 현재
# 17  2023  00536541  재무상태표       비유동부채  제 26 기1분기말            2023.03.31 현재
# 18  2023  00536541  재무상태표        부채총계  제 26 기1분기말            2023.03.31 현재
# 19  2023  00536541  재무상태표         자본금  제 26 기1분기말            2023.03.31 현재
# 20  2023  00536541  재무상태표       이익잉여금  제 26 기1분기말            2023.03.31 현재
# 21  2023  00536541  재무상태표        자본총계  제 26 기1분기말            2023.03.31 현재
# 22  2023  00536541  손익계산서        영업이익   제 26 기1분기  2023.01.01 ~ 2023.03.31
# 23  2023  00536541  손익계산서  법인세차감전 순이익   제 26 기1분기  2023.01.01 ~ 2023.03.31
# 24  2023  00536541  손익계산서       당기순이익   제 26 기1분기  2023.01.01 ~ 2023.03.31
#
#                  당기금액 월평균(백만원)        전기명                     전기일자  \
# 0   4,331,146,051,759  360,928    제 25 기말            2022.12.31 현재
# 1   2,376,932,990,200  198,077    제 25 기말            2022.12.31 현재
# 2   6,708,079,041,959  559,006    제 25 기말            2022.12.31 현재
# 3   2,965,392,294,640  247,116    제 25 기말            2022.12.31 현재
# 4     755,182,004,236   62,931    제 25 기말            2022.12.31 현재
# 5   3,720,574,298,876  310,047    제 25 기말            2022.12.31 현재
# 6      12,938,588,000    1,078    제 25 기말            2022.12.31 현재
# 7     780,777,953,471   65,064    제 25 기말            2022.12.31 현재
# 8   2,987,504,743,083  248,958    제 25 기말            2022.12.31 현재
# 9   2,064,412,867,936  172,034  제 25 기1분기  2022.01.01 ~ 2022.03.31
# 10    182,368,755,762   15,197  제 25 기1분기  2022.01.01 ~ 2022.03.31
# 11    539,627,608,577   44,968  제 25 기1분기  2022.01.01 ~ 2022.03.31
# 12    428,478,384,890   35,706  제 25 기1분기  2022.01.01 ~ 2022.03.31
# 13    531,993,519,339   44,332    제 25 기말            2022.12.31 현재
# 14    791,134,028,608   65,927    제 25 기말            2022.12.31 현재
# 15  1,323,127,547,947  110,260    제 25 기말            2022.12.31 현재
# 16    213,518,635,256   17,793    제 25 기말            2022.12.31 현재
# 17    206,340,661,997   17,195    제 25 기말            2022.12.31 현재
# 18    419,859,297,253   34,988    제 25 기말            2022.12.31 현재
# 19     12,938,588,000    1,078    제 25 기말            2022.12.31 현재
# 20    696,191,752,902   58,015    제 25 기말            2022.12.31 현재
# 21    903,268,250,694   75,272    제 25 기말            2022.12.31 현재
# 22     20,347,007,506    1,695  제 25 기1분기  2022.01.01 ~ 2022.03.31
# 23    395,726,693,267   32,977  제 25 기1분기  2022.01.01 ~ 2022.03.31
# 24    317,863,017,214   26,488  제 25 기1분기  2022.01.01 ~ 2022.03.31
#
#                  전기금액             당기누적금액           전기누적금액
# 0   3,162,551,112,304                NaN              NaN
# 1   2,183,231,490,740                NaN              NaN
# 2   5,345,782,603,044                NaN              NaN
# 3   2,082,665,018,806                NaN              NaN
# 4     741,336,930,529                NaN              NaN
# 5   2,824,001,949,335                NaN              NaN
# 6      12,628,762,500                NaN              NaN
# 7     424,859,393,453                NaN              NaN
# 8   2,521,780,653,709                NaN              NaN
# 9     680,627,292,254  2,064,412,867,936  680,627,292,254
# 10     53,894,068,783    182,368,755,762   53,894,068,783
# 11     49,740,332,819    539,627,608,577   49,740,332,819
# 12     42,767,727,360    428,478,384,890   42,767,727,360
# 13     85,518,930,923                NaN              NaN
# 14    766,097,598,715                NaN              NaN
# 15    851,616,529,638                NaN              NaN
# 16    131,486,088,494                NaN              NaN
# 17    161,898,786,837                NaN              NaN
# 18    293,384,875,331                NaN              NaN
# 19     12,628,762,500                NaN              NaN
# 20    391,212,235,688                NaN              NaN
# 21    558,231,654,307                NaN              NaN
# 22      9,277,688,075     20,347,007,506    9,277,688,075
# 23      8,965,665,455    395,726,693,267    8,965,665,455
# 24      8,405,759,427    317,863,017,214    8,405,759,427
#    사업 연도      회사코드  재무제표명         계정명         당기명                     당기일자  \
# 0   2023  00360674  재무상태표        유동자산  제 24 기1분기말            2023.03.31 현재
# 1   2023  00360674  재무상태표       비유동자산  제 24 기1분기말            2023.03.31 현재
# 2   2023  00360674  재무상태표        자산총계  제 24 기1분기말            2023.03.31 현재
# 3   2023  00360674  재무상태표        유동부채  제 24 기1분기말            2023.03.31 현재
# 4   2023  00360674  재무상태표       비유동부채  제 24 기1분기말            2023.03.31 현재
# 5   2023  00360674  재무상태표        부채총계  제 24 기1분기말            2023.03.31 현재
# 6   2023  00360674  재무상태표        자본총계  제 24 기1분기말            2023.03.31 현재
# 7   2023  00360674  손익계산서         매출액   제 24 기1분기  2023.01.01 ~ 2023.03.31
# 8   2023  00360674  손익계산서        영업이익   제 24 기1분기  2023.01.01 ~ 2023.03.31
# 9   2023  00360674  손익계산서  법인세차감전 순이익   제 24 기1분기  2023.01.01 ~ 2023.03.31
# 10  2023  00360674  손익계산서       당기순이익   제 24 기1분기  2023.01.01 ~ 2023.03.31
# 11  2023  00360674  재무상태표        유동자산  제 24 기1분기말            2023.03.31 현재
# 12  2023  00360674  재무상태표       비유동자산  제 24 기1분기말            2023.03.31 현재
# 13  2023  00360674  재무상태표        자산총계  제 24 기1분기말            2023.03.31 현재
# 14  2023  00360674  재무상태표        유동부채  제 24 기1분기말            2023.03.31 현재
# 15  2023  00360674  재무상태표       비유동부채  제 24 기1분기말            2023.03.31 현재
# 16  2023  00360674  재무상태표        부채총계  제 24 기1분기말            2023.03.31 현재
# 17  2023  00360674  재무상태표         자본금  제 24 기1분기말            2023.03.31 현재
# 18  2023  00360674  재무상태표       이익잉여금  제 24 기1분기말            2023.03.31 현재
# 19  2023  00360674  재무상태표        자본총계  제 24 기1분기말            2023.03.31 현재
# 20  2023  00360674  손익계산서         매출액   제 24 기1분기  2023.01.01 ~ 2023.03.31
# 21  2023  00360674  손익계산서        영업이익   제 24 기1분기  2023.01.01 ~ 2023.03.31
# 22  2023  00360674  손익계산서  법인세차감전 순이익   제 24 기1분기  2023.01.01 ~ 2023.03.31
# 23  2023  00360674  손익계산서       당기순이익   제 24 기1분기  2023.01.01 ~ 2023.03.31
#
#                당기금액 월평균(백만원)        전기명                     전기일자  \
# 0    96,443,351,696    8,036    제 23 기말            2022.12.31 현재
# 1    58,465,865,178    4,872    제 23 기말            2022.12.31 현재
# 2   154,909,216,874   12,909    제 23 기말            2022.12.31 현재
# 3    22,686,478,958    1,890    제 23 기말            2022.12.31 현재
# 4     1,504,505,918      125    제 23 기말            2022.12.31 현재
# 5    24,190,984,876    2,015    제 23 기말            2022.12.31 현재
# 6   130,718,231,998   10,893    제 23 기말            2022.12.31 현재
# 7    10,968,750,133      914  제 23 기1분기  2022.01.01 ~ 2022.03.31
# 8    -2,199,046,889     -184  제 23 기1분기  2022.01.01 ~ 2022.03.31
# 9    -1,894,038,967     -158  제 23 기1분기  2022.01.01 ~ 2022.03.31
# 10     -515,389,918      -43  제 23 기1분기  2022.01.01 ~ 2022.03.31
# 11   96,419,776,324    8,034    제 23 기말            2022.12.31 현재
# 12   58,345,392,697    4,862    제 23 기말            2022.12.31 현재
# 13  154,765,169,021   12,897    제 23 기말            2022.12.31 현재
# 14   22,684,345,233    1,890    제 23 기말            2022.12.31 현재
# 15    1,419,265,205      118    제 23 기말            2022.12.31 현재
# 16   24,103,610,438    2,008    제 23 기말            2022.12.31 현재
# 17    4,898,400,000      408    제 23 기말            2022.12.31 현재
# 18  114,573,389,716    9,547    제 23 기말            2022.12.31 현재
# 19  130,661,558,583   10,888    제 23 기말            2022.12.31 현재
# 20   10,968,750,133      914  제 23 기1분기  2022.01.01 ~ 2022.03.31
# 21   -2,169,065,956     -181  제 23 기1분기  2022.01.01 ~ 2022.03.31
# 22   -1,864,068,464     -156  제 23 기1분기  2022.01.01 ~ 2022.03.31
# 23     -485,419,415      -41  제 23 기1분기  2022.01.01 ~ 2022.03.31
#
#                전기금액          당기누적금액          전기누적금액
# 0   111,476,875,669             NaN             NaN
# 1    57,417,494,160             NaN             NaN
# 2   168,894,369,829             NaN             NaN
# 3    36,001,100,333             NaN             NaN
# 4     1,192,324,830             NaN             NaN
# 5    37,193,425,163             NaN             NaN
# 6   131,700,944,666             NaN             NaN
# 7    11,116,861,302  10,968,750,133  11,116,861,302
# 8    -2,230,368,636  -2,199,046,889  -2,230,368,636
# 9    -2,207,863,535  -1,894,038,967  -2,207,863,535
# 10   -1,221,333,248    -515,389,918  -1,221,333,248
# 11  111,420,814,832             NaN             NaN
# 12   57,296,484,116             NaN             NaN
# 13  168,717,298,948             NaN             NaN
# 14   35,995,914,083             NaN             NaN
# 15    1,107,084,117             NaN             NaN
# 16   37,102,998,200             NaN             NaN
# 17    4,898,400,000             NaN             NaN
# 18  115,526,131,881             NaN             NaN
# 19  131,614,300,748             NaN             NaN
# 20   11,111,261,302  10,968,750,133  11,111,261,302
# 21   -2,169,667,478  -2,169,065,956  -2,169,667,478
# 22   -2,147,223,137  -1,864,068,464  -2,147,223,137
# 23   -1,160,692,850    -485,419,415  -1,160,692,850

# %%
df = pd.DataFrame(result)
df.to_excel('corp_code.xlsx', index=False)
